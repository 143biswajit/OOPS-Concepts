# %% [markdown]
# <a href="https://colab.research.google.com/github/143biswajit/OOPS-Concepts/blob/main/Object__Oriented_Programing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Object_Oriented_Program**
#
# ---

# %% [markdown]
# ![oops image.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **CLASS**
#
# ---

# %% [markdown]
# CLASS IS A BLUEPRINT.(how the object will behave)

# %% [markdown]
# **Class :**
#
# 1. Data or property or attribute
#
# 2. Functionoof behavior or Method.

# %% [markdown]
# **Class basic  structure**

# %% [markdown]
# ![class_method.webp](data:image/webp;base64,...)

# %% [markdown]
# ***CONSTRUCTOR :***
#
# Contructor  is a special method or function , when ever class conver to object  then inside the constructor code will be exicute  autometically.
#
# ---
#
#
#
# ---

# %% [markdown]
# # **OBJECT**
#
# ---

# %% [markdown]
# **OBJECT  IS AN INSTANCE OF CLASS.**

# %% [markdown]
# ![0_sJcCz-q5pIZbgmsK.png](data:image/png;base64,...)

# %% [markdown]
# ***Function :***
# Function are normal funtion , which are not inside the class
#
# ***Method:***
# Method  are basically function , which are written inside  the class.

# %%
class Atm:

  ## __init__ is a constructor :-(constructer is a special function which codes are 
  #autometicaly generated when we make the object of that specific class )
  def __init__(self):

    self.pin = ''
    self.balance = 0

    self.menu()

  def menu(self):
    user_input = input('''

    Hello,how would you like to proceed?
    1.Enter 1 to Create pin
    2.Enter 2 to Deposite
    3.Enter 3 to Withdraw
    4.Enter 4 to Check Balance
    5.Enter 5 to exit

    ''')
    if user_input =="1":
      self.create_pin()
    elif user_input == "2":
      self.deposite()
    elif user_input == "3":
      self.withdraw()
    elif user_input == "4":
      print("Check Balance")
    else:
      print('Bye')
  


  def create_pin(self):
    self.pin=input('Enter your Pin')
    print('Pin set sucefully')

  def deposite(self):
    temp=input('Enter your Pin')
    if temp == self.pin:
      amount = int(input('enter the amount'))
      self.balance = self.balance + amount
      print("Deposite Sucessfully")
    else:
      print('Invalid pin')


  def withdraw(self):
    temp=input('Enter your Pin')
    if temp == self.pin:
      amount=int(input('enter the amount'))
      if amount<self.balance:
        self.balance = self.balance - amount
        print('Withdrawl sucessfull')
      else:
        print("insuffecent funds")
    else:
      print("invalied pin")
        
  def check_balance(self):
    temp=input('Enter your Pin')
    if temp == self.pin:
      print(self.balance)

# %%
sbi =Atm()
# Out:
#     Hello,how would you like to proceed?
#     1.Enter 1 to Create pin
#     2.Enter 2 to Deposite
#     3.Enter 3 to Withdraw
#     4.Enter 4 to Check Balance
#     5.Enter 5 to exit
#
#     1
# Enter your Pin1432
# Pin set sucefully

# %%
sbi.deposite()
# Out:
# Enter your Pin1432
# enter the amount100000
# Deposite Sucessfully

# %%
sbi.check_balance()
# Out:
# Enter your Pin1432
# 100000

# %%
sbi.withdraw()
# Out:
# Enter your Pin1432
# enter the amount70000
# Withdrawl sucessfull

# %%
sbi.withdraw()
# Out:
# Enter your Pin73473
# invalied pin

# %%
sbi.withdraw()
# Out:
# Enter your Pin1432
# enter the amount6789272
# insuffecent funds

# %%
sbi.check_balance()
# Out:
# Enter your Pin1432
# 30000
